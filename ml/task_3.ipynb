# %% [markdown]
# # Машинное обучение, ВМК МГУ
#
# ## Практическое задание 2. Exploratory Data Analysis и линейная регрессия
#
# ### Общая информация
# Дата выдачи: 22.09.2024
#
# Мягкий дедлайн: 23:59MSK 6.10.2024
#
# Жесткий дедлайн: 23:59MSK 13.10.2024

# %% [markdown]
# ### О задании
# В этом задании мы попытаемся научиться анализировать данные и выделять из них полезные признаки. Мы также будем использовать `seaborn` и научимся `sklearn`, а заодно привыкнем к основным понятиям машинного обучения.
#
# ### Оценивание и штрафы
# Каждая из задач имеет определенную «стоимость» (указана в скобках около задачи). Максимально допустимая оценка за работу — **12 баллов + 4.8 бонусов**. Проверяющий имеет право снизить оценку за неэффективную реализацию или неопрятные графики.
#
# **Обратите внимание**, что в каждом разделе домашнего задания есть оцениваниемые задачи и есть вопросы. Вопросы дополняют задачи и направлены на то, чтобы проинтерпретировать или обосновать происходящее. Код без интерпретации не имеет смысла, поэтому отвечать на вопросы обязательно — за отсутствие ответов мы будем снижать баллы за задачи. Если вы ответите на вопросы, но не напишете корректный код к соответствующим оцениваемым задачам, то баллы за такое выставлены не будут.
#
# Сдавать задание после указанного срока сдачи нельзя. При выставлении неполного балла за задание в связи с наличием ошибок на усмотрение проверяющего предусмотрена возможность исправить работу на указанных в ответном письме условиях.
#
# Задание выполняется самостоятельно. «Похожие» решения считаются плагиатом и все задействованные студенты (в том числе те, у кого списали) не могут получить за него больше 0 баллов. Если вы нашли решение какого-то из заданий (или его часть) в открытом источнике, необходимо указать ссылку на этот источник в отдельном блоке в конце вашей работы (скорее всего вы будете не единственным, кто это нашел, поэтому чтобы исключить подозрение в плагиате, необходима ссылка на источник).
#
# <p style="color:#de3815;font-size:25px;">
# Напоминание об оформлении и выполнении ноутбука
# </p>
#
# * Все строчки должны быть выполнены. Нужно, чтобы output команды можно было увидеть, не запуская ячейки (кроме редких случаев, когда необходимо намеренно скрыть ненужный output, про такие случаи желательно писать пояснения в тексте). **В противном случае -1 балл**
# * При оформлении ДЗ нужно пользоваться данным файлом в качестве шаблона. **Не нужно** удалять и видоизменять написанный код и текст, если явно не указана такая возможность. Создавать новые ячейки с кодом/текстов там, где это осмысленно и вы считаете необходимым, конечно, можно. **В противном случае -1 балл**
# * В anytask обязательно нужно прикреплять отдельно файл с расширением ipynb (не в архиве, а именно отдельно). Если необходимо отправить еще какие-то файлы, то вынесите их в отдельный архив (если файлов много) и пришлите. **В противном случае -0.5 балла**
# ---
# * Пишите, пожалуйста, выводы и ответы на вопросы в текстовых ячейках/при помощи print в коде/как результат вывода ячейки. При их отсутствии мы не можем понять, сделали ли вы задание и понимаете, что происходит, и **поэтому будем снижать баллы**
# * Если алгоритм не сказано реализовывать явно, его всегда можно импортировать из библиотеки.
# ---
# * Про графики. _Штрафы будут применяться к каждому результату команды отображения графика (plt.show() и др. аналогичные). Исключением являются графики, генерируемые функциями каких-либо сторонних библиотек, если их нельзя кастомизировать_
#
#     * должно быть название (plt.title) графика; **В противном случае &ndash; -0.05 балла**
#     * на графиках должны быть подписаны оси (plt.xlabel, plt.ylabel); **В противном случае &ndash; -0.025 балла за каждую ось**
#     * должны быть подписаны единицы измерения (если это возможно); **В противном случае &ndash; -0.025 балла за каждую ось**
#     * все названия должны быть понятны любому человеку, знакомому с терминологией, без заглядывания в код; **В противном случае &ndash; -0.05 балла**
#     * подписи тиков на осях не должны сливаться как на одной оси, так и между ними; **В противном случае &ndash; -0.025 балла за каждую ось**
#     * если изображено несколько сущностей на одном холсте (например несколько функций), то необходима поясняющая легенда (plt.legend); **В противном случае &ndash; -0.05 балла**
#     * все линии на графиках должны быть чётко видны (нет похожих цветов или цветов, сливающихся с фоном); **В противном случае &ndash; -0.05 балла**
#     * если отображена величина, имеющая очевидный диапазон значений (например, проценты могут быть от 0 до 100), то желательно масштабировать ось на весь диапазон значений (исключением является случай, когда вам необходимо показать малое отличие, которое незаметно в таких масштабах);
#     * графики должны быть не супер-микро и не супер-макро по размерам, так, чтобы можно было увидеть все, что нужно.
#     * при необходимости улучшения наглядности графиков, можно пользоваться логарифмической шкалой по осям x/y.
#
# ### А также..
#
# * Для удобства поиска вопросов, на которые от вас просят ответа, мы пометили их знаком **(?)**
# * Знак **(!)** означает, что выполнение замечания необходимо для **возможности получения полного балла**
# * Даем до +0.5 баллов за выдающиеся успехи по субъективному мнению проверяющих. Этот **бонус** не апеллируется

# %% [markdown]
# В этом ноутбуке используется библиотека `folium` для визуализации карт. Она работает в google colab!

# %%
# !pip3 install folium

# %%
import folium

m = folium.Map(location=(55.7522200, 37.6155600), zoom_start=10)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# Если вы всё сделали правильно, то выше должна открыться карта Москвы.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

sns.set(style="darkgrid")

# %% [markdown]
# ## Часть 0. Подготовка (1 балл)

# %% [markdown]
# **Задание 1 (1 балл)**.
#
# Мы будем работать с данными из соревнования [New York City Taxi Trip Duration](https://www.kaggle.com/c/nyc-taxi-trip-duration/overview), в котором нужно было предсказать длительность поездки на такси. Скачайте обучающую выборку из этого соревнования и загрузите ее:

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
df = pd.read_csv("/content/drive/MyDrive/cmc/mmro/2/train.csv")

# %% [markdown]
# **(0.1 балл)** Обратите внимание на колонки `pickup_datetime` и `dropoff_datetime`. `dropoff_datetime` был добавлена организаторами только в обучающую выборку, то есть использовать эту колонку нельзя, давайте удалим ее. В `pickup_datetime` записаны дата и время начала поездки. Чтобы с ней было удобно работать, давайте преобразуем даты в `datetime`-объекты

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
df = df.drop(columns=["dropoff_datetime"])
df['pickup_datetime'] = pd.to_datetime(df['pickup_datetime'])

# %% [markdown]
# **(0.2 балла)** В колонке `trip_duration` записано целевое значение, которое мы хотим предсказывать. Давайте посмотрим на распределение таргета в обучающей выборке. Для этого нарисуйте его гистограмму:

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
df['trip_duration'].hist(bins=20)
plt.title("Гистограмма времени поездки")
plt.xlabel("Время поездки, c")
plt.ylabel("Кол-во поездок")
plt.show()

# %% [markdown]
# **Вопрос (0.1 балл)**: **(?)**Что можно сказать о целевой переменной по гистограмме её значений?

# %% [markdown]
# **Ответ**:
#  у целевой переменной есть выбросы в виде поездок длительностью более 200000 секунд. Основные значения находятся от 0 до 200000 секунд

# %% [markdown]
# В соревновании в качестве метрики качества использовалось RMSLE:
# $$\text{RMSLE}(X, y, a) = \sqrt{\frac{1}{\ell}\sum_{i=1}^{\ell} \big(\log{(y_i + 1)} - \log{(a(x_i) + 1)}\big)^2}$$
#
# **Вопрос (0.1 балл)**: **(?)**Как вы думаете, почему авторы соревнования выбрали именно RMSLE, а не RMSE?

# %% [markdown]
# **Ответ:** в данных есть большой разброс значений (видно из гистрограммы), так как в RMSLE используется логарифм, то выбросы станут менее значительны (логарифм величины меньше самой величины). Также более точно оцениваются ошибки: для малой величины большая ошибка будет штрафоваться больше, чем та же ошибка для большой величины (в силу использования логарифма).

# %% [markdown]
# На семинаре мы рассматривали несколько моделей линейной регрессии в `sklearn`, но каждая из них оптимизировала среднеквадратичную ошибку (MSE), а не RMSLE. Давайте проделаем следующий трюк: будем предсказывать не целевую переменную, а ее *логарифм*. Обозначим $\hat{y}_i = \log{(y_i + 1)}$ — модифицированный таргет, а $\hat{a}(x_i)$ — предсказание модели, которая обучалась на $\hat{y}_i$, то есть логарифм таргета. Чтобы предсказать исходное значение, мы можем просто взять экспоненту от нашего предсказания: $a(x_i) = \exp(\hat{a}(x_i)) - 1$.
#
# **Вопрос (0.3 балла)**: **(?)**Покажите, что оптимизация RMSLE для модели $a$ эквивалентна оптимизации MSE для модели $\hat{a}$.
#
# **Доказательство**: Напишие прямо тут в ячейке, при необходимости использовав синтаксис LaTeX в ячейке
#
# ╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
#
# $y$ - настоящее значение
#
# $\hat{y}= \log{(y + 1)}$ - преобразованное настоящее значение
#
# $a$ - предсказание модели
#
# $\hat{a} = \log{(a + 1)}$ - преобразованное предсказание модели
#
# $$\text{RMSLE}(X, y, a) = \sqrt{\frac{1}{\ell}\sum_{i=1}^{\ell} \big(\log{(y_i + 1)} - \log{(a(x_i) + 1)}\big)^2} = \sqrt{\frac{1}{\ell}\sum_{i=1}^{\ell} \big(\hat{y_i}-\hat{a_i}\big)^2}$$
#
# $$\text{MSE}(X, \hat{y}, \hat{a}) = \frac{1}{\ell}\sum_{i=1}^{\ell} \big(\hat{y_i}-\hat{a_i}\big)^2$$
#
# $$\sqrt{\text{MSE}} = \text{RMSLE}$$
#
# Квадратный корень - монотонная возрастающая функцию, следовательно минимизация $\text{MSE}$ эквивалентно минимизации $\sqrt{\text{MSE}}$, то есть минимизации $\text{RMSLE}$. Получаем, что после преобразования $y$ в $\hat{y}$ и $a$ в $\hat{a}$ получаем эквивалетные задачи.

# %% [markdown]
# **(0.1 балл)** Итак, мы смогли свести задачу оптимизации RMSLE к задаче оптимизации MSE, которую мы умеем решать! Кроме того, у логарифмирования таргета есть еще одно полезное свойство. Чтобы его увидеть, добавьте к нашей выборке колонку `log_trip_duration` (воспользуйтесь `np.log1p`) и нарисуйте гистограмму модифицированного таргета по обучающей выборке. Удалите колонку со старым таргетом.

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
df['log_trip_duration'] = np.log1p(df['trip_duration'])
df = df.drop(columns=["trip_duration"])

# %%
df['log_trip_duration'].hist(bins=40)
plt.title("Гистограмма логарифмов времени поездки")
plt.xlabel("Логарифм время поездки, log(cек)")
plt.ylabel("Кол-во поездок")
plt.show()

# %% [markdown]
# **(0.1 балл)** Чтобы иметь некоторую точку отсчета, давайте посчитаем значение метрики MSE при наилучшем константном предсказании:

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
from sklearn.metrics import mean_squared_error
best_constant = np.mean(df['log_trip_duration'])
print("MSE with best constant = %.4f" % mean_squared_error(df['log_trip_duration'], best_constant * np.ones(df['log_trip_duration'].shape)))
# Out:
# MSE with best constant = 0.6332

# %% [markdown]
# ## Часть 1. Изучаем `pickup_datetime` (4 балла)
#
# **Задание 2 (0.5 баллов)**.
#
# **(0.25 баллов)** Для начала давайте посмотрим, сколько всего было поездок в каждый из дней. Постройте график зависимости количества поездок от дня в году (например, можно воспользоваться `sns.countplot`):

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
import datetime as dt
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

plt.figure(figsize=(150, 15))
temp_data = df[['pickup_datetime']].sort_values(by=['pickup_datetime'])
f = sns.countplot(x=temp_data['pickup_datetime'].dt.dayofyear, hue=temp_data['pickup_datetime'].dt.month, palette = 'bright')
f.set_xlabel("Номер дня в году", fontsize=80)
f.set_ylabel("Кол-во поездок, шт", fontsize=80)
f.set_title("Кол-во поездок в каждый из дней", fontsize=130)
f.legend(title='Месяц')
plt.show()
del temp_data

# %% [markdown]
# Вы, вероятно, заметили, что на графике есть 2 периода с аномально маленькими количествами поездок.
#
# **(0.1 балл**)Вычислите, в какие даты происходили эти скачки вниз и найдите информацию о том, что происходило в эти дни в Нью-Йорке.

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
temp_data = df[['pickup_datetime']].sort_values(by=['pickup_datetime'])
date_1 = temp_data['pickup_datetime'].iloc[0].date() + dt.timedelta(days=23 - 1)
date_2 = temp_data['pickup_datetime'].iloc[0].date() + dt.timedelta(days=151 - 1)
print(date_1)
print(date_2)
del temp_data
# Out:
# 2016-01-23
# 2016-05-30

# %%
print('Две даты, в которые проиcходили скачки вниз:', date_1, ',', date_2)
print(date_1, '- в Нью-Йорке в этот день были сильные снегопады и власти запретили движение автомобилей, поэтому были скачки вниз')
print(date_2, '- в Нью-Йорке в этот день была серия вооруженных нападений со стрельбой в некотрых районах, поэтому были скачки вниз')
# Out:
# Две даты, в которые проиcходили скачки вниз: 2016-01-23 , 2016-05-30
# 2016-01-23 - в Нью-Йорке в этот день были сильные снегопады и власти запретили движение автомобилей, поэтому были скачки вниз
# 2016-05-30 - в Нью-Йорке в этот день была серия вооруженных нападений со стрельбой в некотрых районах, поэтому были скачки вниз

# %% [markdown]
# **(0.15 баллов)** Нарисуйте графики зависимости количества поездок от дня недели и от часов в сутках (воспользуйтесь `sns.relplot`):

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
temp_data = df.groupby(by=[df['pickup_datetime'].dt.dayofweek]).count()[['pickup_datetime']]
name_of_day = {
    0: 'Пн',
    1: 'Вт',
    2: 'Ср',
    3: 'Чт',
    4: 'Пт',
    5: 'Сб',
    6: 'Вс'
}
temp_data['day_of_week'] = temp_data.index
temp_data = temp_data.sort_values(by=['day_of_week'])
temp_data['day_of_week'] = temp_data.index.map(name_of_day)
f = sns.relplot(data=temp_data, x='day_of_week', y='pickup_datetime', kind='line', height=5, aspect=1.2)

ticks_for_y = np.linspace(temp_data["pickup_datetime"].min(), temp_data["pickup_datetime"].max(), 8)
f.set(yticks=ticks_for_y, title='Зависимости количества поездок от дня недели', xlabel='День недели',
      ylabel='Кол-во поездок, шт')
plt.show()
del temp_data

# %%
temp_data = df.groupby(by=[df['pickup_datetime'].dt.hour]).count()[['pickup_datetime']]
temp_data['time'] = temp_data.index
temp_data = temp_data.sort_values(by=['time'])
f = sns.relplot(data=temp_data, x='time', y='pickup_datetime', kind='line', height=5, aspect=2)

ticks_for_y = np.linspace(temp_data["pickup_datetime"].min(), temp_data["pickup_datetime"].max(), 8)
f.set(yticks=ticks_for_y, xticks=temp_data['time'], title='Зависимости количества поездок от часа', xlabel='Час в сутках',
      ylabel='Кол-во поездок, шт', xlim=(-0.5, 23.5))
plt.show()
del temp_data

# %% [markdown]
# **Задание 3 (1 балл)**.
#
# * **(0.3 балла)** Нарисуйте на одном графике зависимости количества поездок от часа в сутках для разных месяцев (разные кривые, соответствующие разным месяцам, окрашивайте в разные цвета, воспользуйтесь `hue` в `sns.relplot`).
# * **(0.3 балла)** Аналогично нарисуйте зависимости количества поездок от часа в сутках для разных дней недели.

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
temp_data = pd.DataFrame({
    'month': df['pickup_datetime'].dt.month,
    'hour': df['pickup_datetime'].dt.hour,
})

temp_data = temp_data.groupby(by=['month', 'hour']).size().reset_index(name='count')
temp_data = temp_data.sort_values(by=['hour'])
f = sns.relplot(data=temp_data, x='hour', y='count', kind='line', hue='month', palette = 'bright', height=6, aspect=2)

ticks_for_y = np.linspace(temp_data["count"].min(), temp_data["count"].max(), 8)
f.set(yticks=ticks_for_y, xticks=temp_data['hour'],  title='Зависимости количества поездок от часа в сутках для разных месяцев', xlabel='Час в сутках',
      ylabel='Кол-во поездок, шт',  xlim=(-0.5, 23.5))

f.legend.set_title('Месяц')

plt.show()
del temp_data

# %%
temp_data = pd.DataFrame({
    'day_of_week': df['pickup_datetime'].dt.dayofweek,
    'hour': df['pickup_datetime'].dt.hour,
})


temp_data = temp_data.groupby(by=['day_of_week', 'hour']).size().reset_index(name='count')
name_of_day = {
    0: 'Пн',
    1: 'Вт',
    2: 'Ср',
    3: 'Чт',
    4: 'Пт',
    5: 'Сб',
    6: 'Вс'
}
temp_data['day_of_week'] = temp_data['day_of_week'].map(name_of_day)
temp_data = temp_data.sort_values(by=['hour'])

f = sns.relplot(data=temp_data, x='hour', y='count', kind='line', hue='day_of_week', palette = 'bright', height=6, aspect=2)

ticks_for_y = np.linspace(temp_data["count"].min(), temp_data["count"].max(), 8)
f.set(yticks=ticks_for_y, xticks=temp_data['hour'], title='Зависимости количества поездок от часа в сутках для дней недели', xlabel='Час в сутках',
      ylabel='Кол-во поездок, шт', xlim=(-0.5, 23.5))

f.legend.set_title('День недели')

plt.show()
del temp_data

# %% [markdown]
# **Вопрос  (0.4 балла)**: **(?)** Какие выводы можно сделать, основываясь на графиках выше? Выделяются ли какие-нибудь дни недели? Месяца? Время суток? С чем это связано?

# %% [markdown]
# **Ответ**:
# исходя из графиков можно сделать следующие выводы:
#
#
# *   В **марте** (3-ий месяц) больше всего поездок. Предролагаю, связано с тем, что в марте становится теплее и люди чаще выходят на улицу (погулять/поехать куда-то)
# *   В **январе** (1-ый месяц) и в **июне** (6-ой месяц) меньше поездок. В январе так, потому что холодная погода и люди реже выходят на улицу. В марте так, потому что люди уехжают в отпуск и в Нью-Йорке становится меньше людей.
# *   **С 3-ех до 5-ти** часов люди мало заказывют такси, так как в это время спят
# *   **С 6-ти до 9-ти** часов возрастает кол-во поездок на такси - едут на работу
# *   **C 18-ти до 19-ти** часов возрастает кол-во поездок на такси - люди едут с работы домой
# *  **В субботу и воскресенье** люди утром (до 10-ти часов) реже заказывают такси, так как не надо ехать на работу, в остальные дни утром много заказов.
# *  **В субботу и воскресенье** люди днем (с 10-ти до 15-ти часов) чаще заказывают такси - едут погулять/провести время, в остальные дни в это время меньше заказов - люди на работе.
# * **В воскресенье** после 19-ти часов люди реже заказывают такси, так как не едут никогда перед началом раюочей недели.
# * **В отсальные дни недели** примерно одинаковое кол-во заказов

# %% [markdown]
# **Задание 4 (1.3 балла)**.
#
# **(0.1 балл) за каждый пункт**
# * Разбейте выборку на обучающую и тестовую в отношении 7:3.
# * По обучающей выборке нарисуйте график зависимости среднего логарифма времени поездки от дня недели.
# * Затем сделайте то же самое, но для часа в сутках и дня в году.

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
from sklearn.model_selection import train_test_split
X = df.drop(columns=['id', 'log_trip_duration'])
y = df['log_trip_duration']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=10)

# %%
temp_data = pd.DataFrame({
    'day_of_week': X_train['pickup_datetime'].dt.dayofweek,
    'log_time': y_train,
})


temp_data = temp_data.groupby(by=['day_of_week']).mean().reset_index()
name_of_day = {
    0: 'Пн',
    1: 'Вт',
    2: 'Ср',
    3: 'Чт',
    4: 'Пт',
    5: 'Сб',
    6: 'Вс'
}
temp_data = temp_data.sort_values(by=['day_of_week'])
temp_data['day_of_week'] = temp_data['day_of_week'].map(name_of_day)

f = sns.relplot(data=temp_data, x='day_of_week', y='log_time', kind='line', height=5, aspect=1.2)

ticks_for_y = np.linspace(temp_data["log_time"].min(), temp_data["log_time"].max(), 8)
f.set(yticks=ticks_for_y, title='Зависимость среднего логарифма времени поездки от дня недели \n  в обучающей выборке')

f.set_ylabels('Средний логарифм времени поездки, log(сек)', fontsize=10)
f.set_xlabels('День недели', fontsize=10)

plt.show()
del temp_data

# %%
temp_data = pd.DataFrame({
    'hour': X_train['pickup_datetime'].dt.hour,
    'log_time': y_train,
})

temp_data = temp_data.groupby(by=['hour']).mean().reset_index()
temp_data = temp_data.sort_values(by=['hour'])
f = sns.relplot(data=temp_data, x='hour', y='log_time', kind='line', height=5, aspect=2)

ticks_for_y = np.linspace(temp_data["log_time"].min(), temp_data["log_time"].max(), 8)
f.set(yticks=ticks_for_y, xticks=temp_data['hour'], title='Зависимость среднего логарифма времени поездки от часа в сутках \n  в обучающей выборке',
      xlim=(-0.5, 23.5))

f.set_ylabels('Средний логарифм времени поездки, log(сек)', fontsize=10)
f.set_xlabels('Час в сутках', fontsize=10)

plt.show()
del temp_data

# %%
temp_data = pd.DataFrame({
    'day_of_year': X_train['pickup_datetime'].dt.dayofyear,
    'log_time': y_train,
})

temp_data = temp_data.groupby(by=['day_of_year']).mean().reset_index()
f = sns.relplot(data=temp_data, x='day_of_year', y='log_time', kind='line', height=6, aspect=3.5)

ticks_for_y = np.linspace(temp_data["log_time"].min(), temp_data["log_time"].max(), 8)
f.set(yticks=ticks_for_y, xticks=temp_data['day_of_year'], title='Зависимость среднего логарифма времени поездки от дня в году \n  в обучающей выборке',
      xlim=(0.2, temp_data['day_of_year'].max() + 0.8))

ax = f.axes.flat[0]
for i, name in enumerate(ax.get_xticklabels()):
  name.set_visible(i % 10 == 0)

f.set_ylabels('Средний логарифм времени поездки, log(сек)', fontsize=10)
f.set_xlabels('День в году', fontsize=10)

plt.show()
del temp_data

# %% [markdown]
# **Вопрос (0.3 балла)**: **(?)**Похожи ли графики зависимости таргета от дня недели и от часа в сутках на аналогичные графики для количества поездок? Почему? Что происходит со средним таргетом в те два аномальных периода, что мы видели выше? Почему так происходит? Наблюдаете ли вы какой-нибудь тренд на графике зависимости `log_trip_duration` от номера дня в году?

# %% [markdown]
# **Ответ**:
#
# *   Графики зависимости таргета от дня недели и от часа в сутках **похожи** на аналогичные графики для количества поездок (имеют одинаковые формы), потому что мы усредняем все поездки за час в сутках/день недели и при большом коли-во данных среднее значение длины поездок за каждый час в сутках/день недели будут почти равны - получается графики с таргетом можно получить, "умножив" графики  с кол-вом поездок на среднюю длину поездки за час/день в недели (эта величина, как сказано выше, будет примерно одинаковы для каждого часа/для каждого дня в недели)
# *   Средний таргет в два аномальных периода (23 и 24 января) уменьшает, потому что поездок меньше (имеется не весь спектор возможных длин поездок за день, что повлияло на среднее значение) и поездки короче (в связи с событиями в те дни)
# * На графике зависимости log_trip_duration от номера дня в году имеется постепенно восходящий тред (но о линейсности строго говорить нельзя из-за сильных колебаний), так же видна цикличность

# %% [markdown]
# **(0.1 балл)**
# Добавьте следующие признаки на основе `pickup_datetime`:
# 1. День недели
# 2. Месяц
# 3. Час
# 4. Является ли период аномальным (два бинарных признака, соответствующие двум аномальным периодам)
# 5. Номер дня в году

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
df['day_of_week'] = df['pickup_datetime'].dt.dayofweek
df['month'] = df['pickup_datetime'].dt.month
df['hour'] = df['pickup_datetime'].dt.hour
df['day_of_year'] = df['pickup_datetime'].dt.dayofyear
df['anomaly_1'] = df['pickup_datetime'].dt.dayofyear == 23
df['anomaly_2'] = df['pickup_datetime'].dt.dayofyear == 151

# %% [markdown]
# Итак, мы уже создали некоторое количество признаков.
#
# **Вопрос (0.6 балла)**: **(?)**Какие из признаков стоит рассматривать как категориальные, а какие - как численные? Почему?

# %% [markdown]
# **Ответ**:
#
#
# 1.   День недели - **категориальные** признак, так как имеет ограниченный небольшой диапазон значений (от 0 до 6)
# 2.   Месяц - **категориальные** признак, ттак как имеет ограниченный небольшой диапазон значений (от 1 до 12)
# 3.  Час - **категориальные** признак, ттак как имеет ограниченный небольшой диапазон значений (от 0 до 23)
# 4. Аномальные признаки - **категориальные** признак, так как имеет значения либо True, либо False (не числовые значения).
# 5. Номер дня в году - **числовой** признак, так как имеет числовое значение от 1 до 365 (или 366 в случае высокосного года) - большой диапазон

# %% [markdown]
# **Задание 5 (1.2 балла)**. Обучите `Ridge`-регрессию с параметрами по умолчанию, закодировав все категориальные признаки с помощью `OneHotEncoder`. Численные признаки отмасштабируйте с помощью `StandardScaler`. Используйте только признаки, которые мы выделили в этой части задания.

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.linear_model import Ridge
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

X = df.drop(columns=['id', 'log_trip_duration'])
y = df['log_trip_duration']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=10)

numeric_features = ['day_of_year']
categorical = ['anomaly_1', 'anomaly_2', 'day_of_week', 'month', 'hour']

X_train = X_train[numeric_features + categorical]
X_test = X_test[numeric_features + categorical]

column_transformer = ColumnTransformer([
    ('ohe', OneHotEncoder(handle_unknown="ignore"), categorical),
    ('scaling', StandardScaler(), numeric_features)
])

pipeline = Pipeline(steps=[
    ('ohe_and_scaling', column_transformer),
    ('regression', Ridge())
])

model = pipeline.fit(X_train, y_train)
y_pred = model.predict(X_test)
print("MSE = %.4f" % mean_squared_error(y_test, y_pred))
# Out:
# MSE = 0.6201

# %% [markdown]
# ## Часть 2. Изучаем координаты (3 балла)
# Мы уже очень хорошо изучили данные о времени начала поездки, давайте теперь посмотрим на информацию о координатах начала и конца поездки. Мы подготовили для вас функцию, которая на карте рисует точки начала или конца поездки. Примеры ее вызова вы найдете ниже. Обратите внимание, что в эту функцию мы передаем лишь небольшой кусочек данных, посколько иначе функция будет работать очень долго

# %%
def show_circles_on_map(data, latitude_column, longitude_column, color):
    """
    The function draws map with circles on it.
    The center of the map is the mean of coordinates passed in data.

    data: DataFrame that contains columns latitude_column and longitude_column
    latitude_column: string, the name of column for latitude coordinates
    longitude_column: string, the name of column for longitude coordinates
    color: string, the color of circles to be drawn
    """

    location = (data[latitude_column].mean(), data[longitude_column].mean())
    m = folium.Map(location=location)

    for _, row in data.iterrows():
        folium.Circle(
            radius=100,
            location=(row[latitude_column], row[longitude_column]),
            color=color,
            fill_color=color,
            fill=True
        ).add_to(m)

    return m

# %%
show_circles_on_map(df.sample(1000), "pickup_latitude", "pickup_longitude", "blue")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
show_circles_on_map(df.sample(1000), "dropoff_latitude", "dropoff_longitude", "blue")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# **Вопрос (0.15 балла)**: Какие две точки выделяются на карте?

# %% [markdown]
# **ОТВЕТ:** две точки - два аэропорта: LaGuardia Airport, John F. Kennedy International Airport

# %% [markdown]
# **Задание 6 (0.4 балла)**.
#
# **(0.1 балла)** Как мы все прекрасно помним, $t = s / v_{\text{ср}}$, поэтому очевидно, что самым сильным признаком будет расстояние, которое необходимо проехать. Мы не можем посчитать точное расстояние, которое необходимо преодолеть такси, но мы можем его оценить, посчитав кратчайшее расстояние между точками начала и конца поездки. Чтобы корректно посчитать расстояние между двумя точками на Земле, можно использовать функцию `haversine`. Посчитайте кратчайшее расстояние для объектов и запишите его в колонку `haversine`:

# %%
pip install haversine

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
from haversine import haversine_vector
def temp_haversine(data):
    pickup = data[['pickup_latitude', 'pickup_longitude']].values
    dropoff = data[['dropoff_latitude', 'dropoff_longitude']].values
    return haversine_vector(pickup, dropoff, unit='m')
df['haversine'] = temp_haversine(df)

# %% [markdown]
# **(0.1 балла)** Так как мы предсказываем логарифм времени поездки и хотим, чтобы наши признаки были линейно зависимы с этой целевой переменной, нам нужно логарифмировать расстояние: $\log t = \log s - \log{v_{\text{ср}}}$. Запишите логарифм `haversine` в отдельную колонку:

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
df['log_haversine'] = np.log1p(df['haversine'])

# %% [markdown]
# **(0.2 балла)** Убедимся, что логарифм расстояния лучше коррелирует с нашим таргетом, чем просто расстояние:

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
correlations = df[['haversine', 'log_haversine']].corrwith(df['log_trip_duration'])
f = sns.barplot(y=correlations.index, x=correlations)
f.set(title='Корреляция haversine и log_haversine с таргетом', xlabel="Корреляция", ylabel='')
f.figure.set_size_inches(10, 3)

# %%
print("Для log_haversine корреляция больше, следовательно связь с таргетом выше")
# Out:
# Для log_haversine корреляция больше, следовательно связь с таргетом выше

# %% [markdown]
# **Задание 7 (1 балл)**.
#
# **(0.2 балла)** Давайте изучим среднюю скорость движения такси. Посчитайте среднюю скорость для каждого объекта обучающей выборки, разделив `haversine` на `trip_duration`, и нарисуйте гистограмму ее распределения

# %%
X = df.drop(columns=['id', 'log_trip_duration'])
y = df['log_trip_duration']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=10)

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
X_train['speed'] = (X_train['haversine'] / (np.exp(y_train) - 1)) * 3.6

# %%
X_train['speed'].hist(bins=10)
plt.title("Cреднюю скорость")
plt.xlabel("Логарифм скорости, км/ч")
plt.ylabel("Кол-во поездок")
plt.show()

# %% [markdown]
# **(0.1 балл)** Как можно видеть по гистограмме, для некоторых объектов у нас получились очень больше значения скоростей. Нарисуйте гистограмму по объектам, для которых значение скорости получилось разумным (например, можно не включать рассмотрение объекты, где скорость больше некоторой квантили):

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
X_train['speed'].loc[X_train['speed'] <= X_train['speed'].quantile(0.995)].hist(bins=80)
plt.title("Cреднюю скорость")
plt.xlabel("Логарифм скорости, км/ч")
plt.ylabel("Кол-во поездок")
plt.show()

# %% [markdown]
# **(0.1 балл)** Для каждой пары (день недели, час суток) посчитайте медиану скоростей. Нарисуйте с помощью `sns.heatmap` график, где по осям будут дни недели и часы, а в качестве значения функции - медиана скорости

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
temp_data = X_train.groupby(['day_of_week', 'hour'])['speed'].median().unstack()
name_of_day = {
    0: 'Пн',
    1: 'Вт',
    2: 'Ср',
    3: 'Чт',
    4: 'Пт',
    5: 'Сб',
    6: 'Вс'
}
plt.figure(figsize=(18, 7))
ax = sns.heatmap(temp_data, cmap="YlOrRd", annot=True, fmt=".1f", cbar_kws={'label': 'Медиана скорости, км/ч'})
plt.title('Медианы скоростей дня (день недели, час суток)')
plt.ylabel('День недели')
plt.xlabel('Час в сутках')
ax.set_yticklabels(temp_data.index.map(name_of_day))
plt.show()
del temp_data

# %%
X_train = X_train.drop(columns=['speed'])

# %% [markdown]
# Не забудьте удалить колонку со значением скорости из данных!
#
# **Вопрос (0.35 баллов)**: **(?)** Почему значение скорости нельзя использовать во время обучения?

# %% [markdown]
# **Ответ**:
# Скорость не является значимым призноком, так как она напрямую связана с расстоянием, которое проехала машина, и со временем поездки **без учета пробок**. То есть, используя признак скорости, с большей средней скоростью машина должна проехать большее расстояние (при сравнении поездок с одинаковым временем), но это не всега так в силу возможной загруженности дорог. Мы хотим посторить модель, которая будет предсказывать время поездок для любого уровня трафика - поэтому скорость неподходящий признак.

# %% [markdown]
# **Вопрос (0.1 балл)**: **(?)** Посмотрите внимательно на график и скажите, в какие моменты времени скорость минимальна; максимальна.

# %% [markdown]
# **Ответ**:
#
#
# *   Максимальна: в среду в 12 часов дня
# *   Минимальна: в воскресенье в 6 часов утра

# %% [markdown]
# **(0.15 балл)** Создайте признаки "поездка совершается в период пробок" и "поездка совершается в период свободных дорог" (естественно, они не должен зависеть от скорости!):

# %% [markdown]
# Исходя из графика, можно сделать следующие выводы
#
#
# **Период пробок:** пн-пт 8-19
#
# **Период свободных дорог:** пн-пт 0-6, сб-вс 2-8

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
df['high_traffic'] = (df['day_of_week'] >= 0) & (df['day_of_week'] <= 4) & (df['hour'] >= 8) & (df['hour'] <= 19)
df['low_traffic'] = ((df['day_of_week'] >= 0) & (df['day_of_week'] <= 4) & (df['hour'] >= 0) & (df['hour'] <= 6)) | \
                    ((df['day_of_week'] >= 5) & (df['day_of_week'] <= 6) & (df['hour'] >= 2) & (df['hour'] <= 8))

# %% [markdown]
# **Задание 8 (0.35 балла)**.
#
# **(0.05 балла)** Как уже было замечено выше, на карте выделяются две точки вдали от Манхэттена. Для каждой из них добавьте в выборку два признака: началась ли поездка в ней и закончилась ли она в ней.

# %% [markdown]
# Координаты LaGuardia Airport: (40.7766, -73.8740)
#
#
# Координаты John F. Kennedy International Airport: (40.6397,   -73.7788)

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
df['pickup_LaGuardia'] = (np.abs(df['pickup_latitude'] - 40.7766) < 0.01) & (np.abs(df['pickup_longitude'] + 73.874) < 0.01)
df['pickup_John'] = (np.abs(df['pickup_latitude'] - 40.6397) < 0.01) & (np.abs(df['pickup_longitude'] + 73.7788) < 0.01)

df['dropoff_LaGuardia'] = (np.abs(df['dropoff_latitude'] - 40.7766) < 0.01) & (np.abs(df['dropoff_longitude'] + 73.874) < 0.01)
df['dropoff_John'] = (np.abs(df['dropoff_latitude'] - 40.6397) < 0.01) & (np.abs(df['dropoff_longitude'] + 73.7788) < 0.01)

# %% [markdown]
# **(0.1 балл)** Для каждого из созданных признаков нарисуйте "ящик с усами" (`sns.boxplot`) распределения логарифма времени поездки

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
true_false = {True: 'Да', False: 'Нет'}
info_text = {
    'pickup_LaGuardia' : 'Поездка началась в LaGuardia Airport',
    'pickup_John' : 'Поездка началась в John F. Kennedy International Airport',
    'dropoff_LaGuardia' : 'Поездка закончилась в LaGuardia Airport',
    'dropoff_John' : 'Поездка закончилась в John F. Kennedy International Airport',
}

for name_of_column in ['pickup_LaGuardia', 'pickup_John', 'dropoff_LaGuardia', 'dropoff_John']:
    plt.figure(figsize=(10, 6))

    temp_data = pd.DataFrame({
        'log_trip_duration': df['log_trip_duration'],
        'pic_drop': df[name_of_column].map(true_false)
    })

    sns.boxplot(data=temp_data, x='pic_drop', y='log_trip_duration', hue='pic_drop')
    plt.title(f'Распределение логарифма времени поездки для признака:\n {info_text[name_of_column]}', fontsize=16)
    plt.xlabel(f'{info_text[name_of_column]}?', fontsize=12)
    plt.ylabel('Логарифм времени поездки,log(cек)', fontsize=12)
    plt.show()

# %% [markdown]
# **Вопрос (0.2 балл)**: **(?)** судя по графикам, как вы думаете, хорошими ли получились эти признаки?

# %% [markdown]
# **Ответ**:
# признаки **хорошие**, потому что видно явное разделение распредлений для поездок с конкретным признаком и без него: для каждой категории разные дипазон без выбросов (между усами) - для поездок в/из аэропортов диапазон времени больше; медианы на разном уровне; различаются распределения выбросов (за усами).

# %% [markdown]
# <img src="https://www.dropbox.com/s/xson9nukz5hba7c/map.png?raw=1" align="right" width="20%" style="margin-left: 20px; margin-bottom: 20px">
#
# **Задание 9 (1 балл)**. Сейчас мы почти что не используем сами значения координат. На это есть несколько причин: по отдельности рассматривать широту и долготу не имеет особого смысла, стоит рассматривать их вместе. Во-вторых, понятно, что зависимость между нашим таргетом и координатами не линейная. Чтобы как-то использовать координаты, можно прибегнуть к следующему трюку: обрамим область с наибольшим количеством поездок прямоугольником (как на рисунке). Разобьем этот прямоугольник на ячейки. Каждой точке сопоставим номер ее ячейки, а тем точкам, что не попали ни в одну из ячеек, сопоставим значение -1.
#
# Напишите трансформер, который сначала разбивает показанную на рисунке область на ячейки, а затем создает два признака: номер ячейки, в которой началась поездка, и номер ячейки, в которой закончилась поездка. Количество строк и столбцов выберите самостоятельно.
#
# Обратите внимание, что все вычисления должны быть векторизованными, трансформер не должен модифицировать передаваемую ему выборку inplace, а все необходимые статистики (если они вдруг нужны) нужно считать только по обучающей выборке в методе `fit`:

# %%
from sklearn.base import BaseEstimator, TransformerMixin

class MapGridTransformer(BaseEstimator, TransformerMixin):
    #╰( ͡° ͜ʖ ͡° )つ──☆*:
    def __init__(self, rows, columns):
      self.rows = rows
      self.columns = columns

    def fit(self, X, y=None):
      temp_latitude = X[['pickup_latitude', 'dropoff_latitude']].values.flatten()
      self.min_of_latitude = np.percentile(temp_latitude, 1)
      self.max_of_latitude = np.percentile(temp_latitude, 99)

      temp_longitude = X[['pickup_longitude', 'dropoff_longitude']].values.flatten()
      self.min_of_longitude = np.percentile(temp_longitude, 1)
      self.max_of_longitude = np.percentile(temp_longitude, 99)
      return self

    def transform(self, X):
        len_of_step_latitude = (self.max_of_latitude - self.min_of_latitude) / self.rows
        len_of_step_longitude = (self.max_of_longitude - self.min_of_longitude) / self.columns

        pickup_row = ((X['pickup_latitude'].values - self.min_of_latitude) / len_of_step_latitude).astype(int)
        pickup_column = ((X['pickup_longitude'].values - self.min_of_longitude) / len_of_step_longitude).astype(int)
        dropoff_row = ((X['dropoff_latitude'].values - self.min_of_latitude) / len_of_step_latitude).astype(int)
        dropoff_column = ((X['dropoff_longitude'].values - self.min_of_longitude) / len_of_step_longitude).astype(int)

        pickup_cell = np.where(((pickup_row >= 0) & (pickup_row < self.rows) & (pickup_column >= 0) & (pickup_column < self.columns)),\
                              pickup_row * self.columns + pickup_column, -1)
        dropoff_cell = np.where(((dropoff_row >= 0) & (dropoff_row < self.rows) & (dropoff_column >= 0) & (dropoff_column < self.columns)),\
                                dropoff_row * self.columns + dropoff_column, -1)

        return np.column_stack((pickup_cell, dropoff_cell))

# %%
mgt_transformer = MapGridTransformer(rows=20, columns=20)
mgt_transformer.fit(df)
cells = mgt_transformer.transform(df)
df['pickup_cell'] = cells[:, 0]
df['dropoff_cell'] = cells[:, 1]

# %% [markdown]
# **Задание 10 (0.1 балла)**. Обучите `Ridge`-регрессию со стандартными параметрами на признаках, которые мы выделили к текущему моменту, закодировав категориальные признаки с помощью `OneHotEncoder`. Численные признаки отмасштабируйте с помощью `StandardScaler`.

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
X = df.drop(columns=['id', 'log_trip_duration'])
y = df['log_trip_duration']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=10)

numeric_features = ['day_of_year', 'log_haversine']
categorical = ['anomaly_1', 'anomaly_2',  'month', 'hour', 'day_of_week', 'high_traffic', 'low_traffic', 'pickup_LaGuardia', 'pickup_John',
               'dropoff_LaGuardia', 'dropoff_John', 'pickup_cell', 'dropoff_cell']
X_train = X_train[numeric_features + categorical]
X_test = X_test[numeric_features + categorical]

column_transformer = ColumnTransformer([
    ('ohe', OneHotEncoder(handle_unknown="ignore"), categorical),
    ('scaling', StandardScaler(), numeric_features)
])

pipeline = Pipeline(steps=[
    ('ohe_and_scaling', column_transformer),
    ('regression', Ridge())
])

model = pipeline.fit(X_train, y_train)
y_pred = model.predict(X_test)
print("MSE = %.4f" % mean_squared_error(y_test, y_pred))
# Out:
# MSE = 0.2587

# %% [markdown]
# ## Часть 3. Изучаем оставшиеся признаки (1 балл)
#
# **Задание 11 (0.85 баллов)**.
#
# У нас осталось еще 3 признака, которые мы не исследовали: `vendor_id`, `passenger_count` и `store_and_fwd_flag`.
#
# **Вопрос (0.3 балла)**: **(?)** Подумайте, почему каждый из этих признаков может быть потенциально полезным.
#
# **Ответ**:
#
# `vendor_id` - может быть полезен, так как разные поставщики предоставлять услоги такси в большей степени для относительно длинных/котротких поездок (исходя из политики компании)
#
# `passenger_count` - может быть полезен, так как компаниями обычно едут куда-то в дальнее место на отдых (например в аэропорт), на работу, учебу (относительно короткие поездки) обычно едут по одному (из дома например)
#
# `store_and_fwd_flag` - может быть полезен, так как значения этой колонки определяются от части тем, было ли соединение с сервером у машины. Если соединения не было, то можно предположить, что машина находится далеко от центра, где соединение нестабильное - то есть вез пассажира куда-то в отдальнное от центра место (длинная поездка)

# %% [markdown]
# **(0.1 балл)** Посчитайте, сколько есть уникальных значений у каждого из этих признаков:

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
temp_data = ['vendor_id', 'passenger_count', 'store_and_fwd_flag']
for elem in temp_data:
  print(f'Кол-во уникальных значений для {elem}: {df[elem].nunique(dropna=False)}')
del temp_data
# Out:
# Кол-во уникальных значений для vendor_id: 2
# Кол-во уникальных значений для passenger_count: 10
# Кол-во уникальных значений для store_and_fwd_flag: 2

# %% [markdown]
# **(0.05 балла)** Постройте "ящики с усами" распределений логарифма времени поездки в зависимости от значений каждого из признаков

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
for name_of_column in ['vendor_id', 'passenger_count', 'store_and_fwd_flag']:
    plt.figure(figsize=(10, 6))

    temp_data = pd.DataFrame({
        'log_trip_duration': df['log_trip_duration'],
        'info': df[name_of_column]
    })

    sns.boxplot(data=temp_data, x='info', y='log_trip_duration', hue='info')
    plt.title(f'Распределение логарифма времени поездки для признака: {name_of_column}', fontsize=16)
    plt.xlabel(name_of_column, fontsize=12)
    plt.ylabel('Логарифм времени поездки,log(cек)', fontsize=12)
    if temp_data['info'].nunique(dropna=False) > 2:
      plt.legend(title=name_of_column)
    plt.show()

# %% [markdown]
# **(0.05 балла)** Переведите признаки `vendor_id` и `store_and_fwd_flag` в значения $\{0;1\}$

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
df['vendor_id'] = np.where(df['vendor_id'] == 1, 0, 1)
df['store_and_fwd_flag'] = np.where(df['store_and_fwd_flag'] == 'N', 0, 1)

# %% [markdown]
# **Вопрос (0.35 балла)**: **(?)** Основываясь на графиках выше, как вы думаете, будут ли эти признаки сильными? Ответ обосновать.

# %% [markdown]
# **Ответ**:
# предпологаю, что признаки не будут сильными, так как распределение исзодя из значения конкретного признака почти не отличаютс. Так же почти не отличаются дипазоны без выбросов, выбросы и медианы. Среди этих трех признаков самым сильным будет `passenger_count`, так как наиболее отличающиеся распределния для значений.

# %% [markdown]
# **Задание 12 (0.15 баллов)**. Проверьте свои предположения, обучив модель **в том числе и на этих трех признаках.** Обучайте `Ridge`-регрессию со стандартными параметрами, закодировав  категориальные признаки с помощью `OneHotEncoder`. Численные признаки отмасштабируйте с помощью `StandardScaler`.

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
from sklearn.linear_model import Ridge
def train_model(numeric_features):
  X = df.drop(columns=['id', 'log_trip_duration'])
  y = df['log_trip_duration']
  X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=10)

  categorical = ['anomaly_1', 'anomaly_2',  'month', 'hour', 'day_of_week', 'high_traffic', 'low_traffic', 'pickup_LaGuardia', 'pickup_John',
                'dropoff_LaGuardia', 'dropoff_John', 'pickup_cell', 'dropoff_cell']
  X_train = X_train[numeric_features + categorical]
  X_test = X_test[numeric_features + categorical]

  column_transformer = ColumnTransformer([
      ('ohe', OneHotEncoder(handle_unknown="ignore"), categorical),
      ('scaling', StandardScaler(), numeric_features)
  ])

  pipeline = Pipeline(steps=[
      ('ohe_and_scaling', column_transformer),
      ('regression', Ridge())
  ])

  model = pipeline.fit(X_train, y_train)
  y_pred = model.predict(X_test)
  return mean_squared_error(y_test, y_pred)


print("Без добавления этих признаков: MSE = %.8f" \
      % train_model(['day_of_year', 'log_haversine']))

print("С добавением vendor_id: MSE = %.8f" \
      % train_model(['day_of_year', 'log_haversine', 'vendor_id']))

print("С добавением passenger_count: MSE = %.8f" \
      % train_model(['day_of_year', 'log_haversine', 'passenger_count']))

print("С добавением store_and_fwd_flag: MSE = %.8f" \
      % train_model(['day_of_year', 'log_haversine', 'store_and_fwd_flag']))

print("С добавением vendor_id, passenger_count, store_and_fwd_flag: MSE = %.8f" \
      % train_model(['day_of_year', 'log_haversine', 'vendor_id', 'passenger_count', 'store_and_fwd_flag']))

print("С добавением vendor_id, passenger_count: MSE = %.8f" \
      % train_model(['day_of_year', 'log_haversine', 'vendor_id', 'passenger_count']))

print("С добавением passenger_count, store_and_fwd_flag: MSE = %.8f" \
      % train_model(['day_of_year', 'log_haversine', 'passenger_count', 'store_and_fwd_flag']))

print("С добавением vendor_id, store_and_fwd_flag: MSE = %.8f" \
      % train_model(['day_of_year', 'log_haversine', 'vendor_id', 'store_and_fwd_flag']))
# Out:
# Без добавления этих признаков: MSE = 0.25871929
# С добавением vendor_id: MSE = 0.25860336
# С добавением passenger_count: MSE = 0.25860877
# С добавением store_and_fwd_flag: MSE = 0.25871848
# С добавением vendor_id, passenger_count, store_and_fwd_flag: MSE = 0.25853031
# С добавением vendor_id, passenger_count: MSE = 0.25854336
# С добавением passenger_count, store_and_fwd_flag: MSE = 0.25862030
# С добавением vendor_id, store_and_fwd_flag: MSE = 0.25858958

# %% [markdown]
# Исходя из полученных данных MSE становится меньше (незначительно) при добавлении любого из трех признаков (лучше всего влияет на результат `passenger_count`). Лучше всего модель обучается при добалении **всех трех признаков.**

# %% [markdown]
# Если признаки не дали какого-то ощутимого улучшения метрики, их можно выбросить из данных.

# %% [markdown]
# ## Часть 4. Улучшаем модель (2.7 баллов)

# %% [markdown]
# **Задание 13 (0.7 баллов)**.
#
# В наших данных есть нетипичные объекты: с аномально маленьким времени поездки, с очень большим пройденным расстоянием или очень большими остатками регрессии. В этом задании предлагается исключить такие объекты из обучающей выборки.
#
#
# **(0.3 балла)** Для этого нарисуйте гистограммы распределения упомянутых выше величин, выберите объекты, которые можно назвать выбросами, и очистите обучающую выборку от них.
#
# Отметим, что хотя эти объекты и выглядят как выбросы, в тестовой выборке тоже скорее всего будут объекты с такими же странными значениями целевой переменной и/или признаков. Поэтому, возможно, чистка обучающей выборки приведёт к ухудшению качества на тесте. Тем не менее, всё равно лучше удалять выбросы из обучения, чтобы модель получалась более разумной и интерпретируемой.

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
df['log_trip_duration'].hist(bins=40)
plt.title("Гистограммы распределения логарифма времени поездки")
plt.xlabel("Логарифм времени поездки, log(c)")
plt.ylabel("Кол-во поездок")
plt.show()

# %%
df['log_haversine'].hist(bins=40)
plt.title("Гистограммы распределения логарифма пройденного расстояния")
plt.xlabel("Логарифм пройденного расстояния, log(м)")
plt.ylabel("Кол-во поездок")
plt.show()

# %%
X = df.drop(columns=['id', 'log_trip_duration'])
y = df['log_trip_duration']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=10)

numeric_features = ['day_of_year', 'log_haversine', 'vendor_id', 'passenger_count', 'store_and_fwd_flag']

categorical = ['anomaly_1', 'anomaly_2',  'month', 'hour', 'day_of_week', 'high_traffic', 'low_traffic', 'pickup_LaGuardia', 'pickup_John',
               'dropoff_LaGuardia', 'dropoff_John', 'pickup_cell', 'dropoff_cell']
X_train = X_train[numeric_features + categorical]
X_test = X_test[numeric_features + categorical]

column_transformer = ColumnTransformer([
    ('ohe', OneHotEncoder(handle_unknown="ignore"), categorical),
    ('scaling', StandardScaler(), numeric_features)
])

pipeline = Pipeline(steps=[
    ('ohe_and_scaling', column_transformer),
    ('regression', Ridge())
])

model = pipeline.fit(X_train, y_train)
y_pred = model.predict(X)

temp_data = y - y_pred
temp_data.hist(bins=40)
plt.title("Гистограммы распределения остатка регрессии")
plt.xlabel("Остаток регрессии")
plt.ylabel("Кол-во поездок")
plt.show()
del temp_data

# %%
df = df[df['log_trip_duration'] > 3]
df = df[df['log_haversine'] < 11]
df['regression_residual'] = np.abs(y - y_pred)
df = df[df['regression_residual'] < 2]
df = df.drop(columns=['regression_residual'])

# %% [markdown]
# **(0.3 балла)** Сейчас у нас очень много категориальных признаков. В категориальных признаках могут содержаться редкие категории, обычно это плохо: модель сильно переобучается на таких примерах. Попробуйте объединить редкие категории в одну. Естественно, делать это нужно только для действительно редких категорий.

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
categorical = ['anomaly_1', 'anomaly_2',  'month', 'hour', 'day_of_week', 'high_traffic', 'low_traffic', 'pickup_LaGuardia', 'pickup_John',
               'dropoff_LaGuardia', 'dropoff_John', 'pickup_cell', 'dropoff_cell']
for temp in categorical:
  value_counts = df[temp].value_counts(normalize=True)
  rare_values = value_counts[value_counts < 0.015].index
  if len(rare_values) > 1:
    df[temp] = df[temp].replace(rare_values, rare_values[0])

# %% [markdown]
# **(0.1 балла)**Обучите модель на очищенных данных и посчитайте качество на тестовой выборке.

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
X = df.drop(columns=['id', 'log_trip_duration'])
y = df['log_trip_duration']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=10)

numeric_features = ['day_of_year', 'log_haversine']
categorical = ['anomaly_1', 'anomaly_2',  'month', 'hour', 'day_of_week', 'high_traffic', 'low_traffic', 'pickup_LaGuardia', 'pickup_John',
               'dropoff_LaGuardia', 'dropoff_John', 'pickup_cell', 'dropoff_cell']
X_train = X_train[numeric_features + categorical]
X_test = X_test[numeric_features + categorical]

column_transformer = ColumnTransformer([
    ('ohe', OneHotEncoder(handle_unknown="ignore"), categorical),
    ('scaling', StandardScaler(), numeric_features)
])

pipeline = Pipeline(steps=[
    ('ohe_and_scaling', column_transformer),
    ('regression', Ridge())
])

model = pipeline.fit(X_train, y_train)
y_pred = model.predict(X_test)
print("MSE = %.4f" % mean_squared_error(y_test, y_pred))
# Out:
# MSE = 0.1587

# %% [markdown]
# **Задание 14 (1 балл)**.
#
# **(0.1 балл)** После OneHot-кодирования количество признаков в нашем датасете сильно возрастает. Посчитайте колиество признаков до и после кодирования категориальных признаков.

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
X = df.drop(columns=['id', 'log_trip_duration'])
y = df['log_trip_duration']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=10)

numeric_features = ['day_of_year', 'log_haversine']
categorical = ['anomaly_1', 'anomaly_2',  'month', 'hour', 'day_of_week', 'high_traffic', 'low_traffic', 'pickup_LaGuardia', 'pickup_John',
               'dropoff_LaGuardia', 'dropoff_John', 'pickup_cell', 'dropoff_cell']
X_train = X_train[numeric_features + categorical]
print("Кол-во признаковв до OneHot-кодирования:", X_train.shape[1])

encoder = OneHotEncoder(handle_unknown='ignore')
X_train_new = encoder.fit_transform(X_train[categorical]).toarray()
print("Кол-во признаковв после OneHot-кодирования:", X_train_new.shape[1] + len(numeric_features))
# Out:
# Кол-во признаковв до OneHot-кодирования: 15
# Кол-во признаковв после OneHot-кодирования: 105

# %% [markdown]
# **(0.2 балла)** Попробуйте обучить не `Ridge`-, а `Lasso`-регрессию. **(?)** Какой метод лучше?

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
from sklearn.linear_model import Ridge
X = df.drop(columns=['id', 'log_trip_duration'])
y = df['log_trip_duration']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=10)

numeric_features = ['day_of_year', 'log_haversine']
categorical = ['anomaly_1', 'anomaly_2',  'month', 'hour', 'day_of_week', 'high_traffic', 'low_traffic', 'pickup_LaGuardia', 'pickup_John',
               'dropoff_LaGuardia', 'dropoff_John', 'pickup_cell', 'dropoff_cell']
X_train = X_train[numeric_features + categorical]
X_test = X_test[numeric_features + categorical]

column_transformer = ColumnTransformer([
    ('ohe', OneHotEncoder(handle_unknown="ignore"), categorical),
    ('scaling', StandardScaler(), numeric_features)
])

pipeline = Pipeline(steps=[
    ('ohe_and_scaling', column_transformer),
    ('regression', Ridge())
])

model = pipeline.fit(X_train, y_train)
y_pred = model.predict(X_test)
print("Ridge MSE = %.4f" % mean_squared_error(y_test, y_pred))
# Out:
# Ridge MSE = 0.1587

# %%
from sklearn.linear_model import Lasso
X = df.drop(columns=['id', 'log_trip_duration'])
y = df['log_trip_duration']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=10)

numeric_features = ['day_of_year', 'log_haversine']
categorical = ['anomaly_1', 'anomaly_2',  'month', 'hour', 'day_of_week', 'high_traffic', 'low_traffic', 'pickup_LaGuardia', 'pickup_John',
               'dropoff_LaGuardia', 'dropoff_John', 'pickup_cell', 'dropoff_cell']
X_train = X_train[numeric_features + categorical]
X_test = X_test[numeric_features + categorical]

column_transformer = ColumnTransformer([
    ('ohe', OneHotEncoder(handle_unknown="ignore"), categorical),
    ('scaling', StandardScaler(), numeric_features)
])

pipeline = Pipeline(steps=[
    ('ohe_and_scaling', column_transformer),
    ('regression', Lasso())
])

model = pipeline.fit(X_train, y_train)
y_pred = model.predict(X_test)
print("Lasso MSE = %.4f" % mean_squared_error(y_test, y_pred))
# Out:
# Lasso MSE = 0.5551

# %% [markdown]
# **Ответ**:
# Ridge регрессия дает меньшее значние MSE, поэтому она лучше

# %% [markdown]
# **(0.2 балла)** Разбейте обучающую выборку на обучающую и валидационную в отношении 8:2. По валидационной выборке подберите оптимальные значения параметра регуляризации (по логарифмической сетке) отдельно для `Ridge` и отдельно для `Lasso`, на тестовой выборке измерьте качество лучшей полученной модели.

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
X = df.drop(columns=['id', 'log_trip_duration'])
y = df['log_trip_duration']
X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, test_size=0.3, random_state=10)
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.2, random_state=42)

numeric_features = ['day_of_year', 'log_haversine']
categorical = ['anomaly_1', 'anomaly_2',  'month', 'hour', 'day_of_week', 'high_traffic', 'low_traffic', 'pickup_LaGuardia', 'pickup_John',
               'dropoff_LaGuardia', 'dropoff_John', 'pickup_cell', 'dropoff_cell']
X_train = X_train[numeric_features + categorical]
X_test = X_test[numeric_features + categorical]
X_val = X_val[numeric_features + categorical]


column_transformer = ColumnTransformer([
    ('ohe', OneHotEncoder(handle_unknown="ignore"), categorical),
    ('scaling', StandardScaler(), numeric_features)
])

def create_model(model, param):
    best_alpha = None
    best_model = None
    best_val_mse = float('inf')

    for alpha in param['alpha']:
        pipeline = Pipeline([
            ('data', column_transformer),
            ('model', model(alpha=alpha))
        ])
        pipeline.fit(X_train, y_train)
        val_pred = pipeline.predict(X_val)
        val_mse = mean_squared_error(y_val, val_pred)

        if val_mse < best_val_mse:
            best_val_mse = val_mse
            best_alpha = alpha
            best_model = pipeline

    test_pred = best_model.predict(X_test)
    test_mse = mean_squared_error(y_test, test_pred)

    return best_alpha, best_val_mse, test_mse

param = {'alpha': np.logspace(-3, 3, 15)}

ridge_best_params, ridge_val_mse, ridge_test_mse = create_model(Ridge, param)

print("Ridge")
print(f"Лучший параметр: {ridge_best_params}")
print(f"Val MSE: {ridge_val_mse:.4f}")
print(f"Test MSE: {ridge_test_mse:.4f}")

lasso_best_params, lasso_val_mse, lasso_test_mse = create_model(Lasso, param)

print("\nLasso")
print(f"Лучший параметр: {lasso_best_params}")
print(f"Val MSE: {lasso_val_mse:.4f}")
print(f"Test MSE: {lasso_test_mse:.4f}")
# Out:
# Ridge
# Лучший параметр: 0.001
# Val MSE: 0.1570
# Test MSE: 0.1587
#
# Lasso
# Лучший параметр: 0.001
# Val MSE: 0.1594
# Test MSE: 0.1610

# %% [markdown]
# **(0.2 балла)** Для каждого перебранного `alpha` для Lasso посчитайте количество нулевых весов в модели и нарисуйте график зависимости его от `alpha`. **(?)(0.3)** Как сильно придётся потерять в качестве, если мы хотим с помощью Lasso избавиться хотя бы от половины признаков?

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・
X = df.drop(columns=['id', 'log_trip_duration'])
y = df['log_trip_duration']
X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, test_size=0.3, random_state=10)
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.2, random_state=42)

numeric_features = ['day_of_year', 'log_haversine']
categorical = ['anomaly_1', 'anomaly_2',  'month', 'hour', 'day_of_week', 'high_traffic', 'low_traffic', 'pickup_LaGuardia', 'pickup_John',
               'dropoff_LaGuardia', 'dropoff_John', 'pickup_cell', 'dropoff_cell']
X_train = X_train[numeric_features + categorical]
X_test = X_test[numeric_features + categorical]
X_val = X_val[numeric_features + categorical]


column_transformer = ColumnTransformer([
    ('ohe', OneHotEncoder(handle_unknown="ignore"), categorical),
    ('scaling', StandardScaler(), numeric_features)
])

zero_weights = []
alphas = np.logspace(-3, 3, 30)
for elem in alfas:
    pipeline = Pipeline([
        ('data', column_transformer),
        ('model', Lasso(alpha=elem))
    ])

    pipeline.fit(X_train, y_train)
    weights = pipeline.named_steps['model'].coef_
    zero_weights.append(np.sum(weights == 0))

plt.figure(figsize=(11, 8))
plt.plot(alphas, zero_weights, marker='o')
plt.xscale('log')
plt.grid(True)

plt.xlabel('Alpha')
plt.ylabel('Кол-во нулевых весов')

plt.title('Зависимость количества нулевых весов от alpha в Lasso регрессии')
plt.grid(True)
plt.show()

# %%
alphas = np.logspace(-3, 3, 30)
results = []

for elem in alphas:
    pipeline = Pipeline([
        ('data', column_transformer),
        ('model', Lasso(alpha=elem))
    ])
    pipeline.fit(X_train, y_train)

    weights = pipeline.named_steps['model'].coef_
    no_zero_weights = np.sum(weights != 0)

    y_pred_val = pipeline.predict(X_val)
    results.append({
        'alpha': elem,
        'non_zero_weights': no_zero_weights,
        'mse': mean_squared_error(y_val, y_pred_val)
    })

total_features = len(weights)
half_features = total_features / 2

for elem in results:
    if elem['non_zero_weights'] <= half_features:
        target_result = elem
        break

min_alpha_mse = results[0]['mse']
target_mse = target_result['mse']
print('Избавимся от половины признаков. MSE увеличится на:', target_mse - min_alpha_mse)
# Out:
# Избавимся от половины признаков. MSE увеличится на: 0.0019998269106827893

# %% [markdown]
#  Если мы хотим с помощью Lasso избавиться хотя бы от половины признаков, то мы **потеряем** в качестве (незначительно)

# %% [markdown]
# <img src="https://www.dropbox.com/s/wp4jj0599np17lh/map_direction.png?raw=1" width="20%" align="right" style="margin-left: 20px">
#
# **Задание 15 (1 балл + 1 бонус)**.
#
# **(0.4 баллов)** Часто бывает полезным использовать взаимодействия признаков (feature interactions), то есть строить новые признаки на основе уже существующих. Выше мы разбили карту Манхэттена на ячейки и придумали признаки "из какой ячейки началась поездка" и "в какой ячейке закончилась поездка".
#
# Давайте попробуем сделать следующее: посчитаем, сколько раз встречается каждая возможная пара этих признаков в нашем датасете и выберем 100 самых частых пар. Закодируем поездки с этими частыми парами как категориальный признак, остальным объектам припишем -1. Получается, что мы закодировали, откуда и куда должно было ехать такси.
#
# Также можете придумать ещё какой-нибудь способ сделать признаки про маршрут. Если эти признаки будут давать хороший прирост в качестве, то за это могут быть даны дополнительные бонусные баллы **(до 1 бонусного балла)**

# %%
temp_data = df['pickup_cell'].astype(str) + '_' + df['dropoff_cell'].astype(str)
count = temp_data.value_counts()
top = count.sort_values(ascending=False).head(100)
pairs = {}
for i, elem in  enumerate(top.index):
  pairs[elem] = i
df['pairs'] = np.where(temp_data.isin(pairs), temp_data.map(pairs), -1)
del temp_data

# %% [markdown]
# **Вопрос (0.5 балла)**: **(?)** Почему такой признак потенциально полезный? Почему линейная модель не может самостоятельно "вытащить" эту информацию, ведь у нее в распоряжении есть признаки "из какой ячейки началась поездка" и "в какой ячейке закончилась поездка"?

# %% [markdown]
# **Ответ**: этот признак позволяет учитывать неленейную зависимость между начальной и конечной точками (линейные модели не способны сами вытащить нелинейную информацию). Так же этот признак уменьшает размерность выборки (меньше вычислений). Мы группируем редкие (у редких значение -1), что дает возможность модели обрабатывать эти нетипичные случаи. Также группирую наиболее частые точки для поездок (и ставя редким значение -1), мы делаем своего рода регуляризацию. Эти наиболее частые поездки могут иметь более сложную стурктуру (пробки, какие-то другие ситуации), так как по ним часто ездят - и мы даем возмонжость модели наиболее точно посторить для таких случаев зависимости.
#
#
# Линейная модель не может самостоятельно "вытащить" эту информацию, так как признак, который мы посторили не является линейным (был построен из двух колонок).

# %% [markdown]
# **(0.1 балл)** Заново обучите модель (`Ridge`, если она дала более высокое качество в предыдущих экспериментах, и `Lasso` иначе) на новых даннных и посчитайте качество на тестовой выборке

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
X = df.drop(columns=['id', 'log_trip_duration'])
y = df['log_trip_duration']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=10)

numeric_features = ['day_of_year', 'log_haversine']
categorical = ['anomaly_1', 'anomaly_2',  'month', 'hour', 'day_of_week', 'high_traffic', 'low_traffic', 'pickup_LaGuardia', 'pickup_John',
               'dropoff_LaGuardia', 'dropoff_John', 'pairs']
X_train = X_train[numeric_features + categorical]
X_test = X_test[numeric_features + categorical]

column_transformer = ColumnTransformer([
    ('ohe', OneHotEncoder(handle_unknown="ignore"), categorical),
    ('scaling', StandardScaler(), numeric_features)
])

pipeline = Pipeline(steps=[
    ('ohe_and_scaling', column_transformer),
    ('regression', Ridge())
])

model = pipeline.fit(X_train, y_train)
y_pred = model.predict(X_test)
print("MSE = %.4f" % mean_squared_error(y_test, y_pred))
# Out:
# MSE = 0.1581

# %% [markdown]
# **Задание 16 (бонус, 1 балл)**. Где, как не для нашей задачи, считать манхэттенское расстояние?
#
# **Вопрос (0.2 балла)**: **(?)** Найдите, что такое манхэттенское расстояние и почему оно так называется. Как оно нам может помочь?
#
# **Ответ**:
# Две точки (x1, y1) и (x2, y2). Манхэттенское расстояние считается как |x1-x2|+|y1-y2|. Оно так называется, так как улицы в Манхэттена, сделаны так, что такси должно двигаться только вдоль этих улиц. Оно поможет тем, что мы сможем частично определить как двигалась машина - еще один признак.

# %% [markdown]
# **(0.5 балла)** Введите систему координат на нашей карте так, чтобы оси были параллельны улицам Манхэттена, и добавьте сначала в данные признак "манхэттенское расстояние между пунктом отправления и пунктом назначения", а затем и логарифм этого признака. Посчитайте корреляцию между вашим новыми признаком и таргетом; между `log_haversine` и таргетом. В каком случае корреляция больше?
#
# Нарисуйте карту, где покажете выбранные оси. Чтобы мы могли проверить вашу работу, просьба сделать скрин этой карты и приложить картинку (если мы откроем ваш ноутбук, виджеты отображаться не будут).

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ

# %% [markdown]
# **(0.3 балла)** Заново обучите модель на новых даннных и посчитайте качество на тестовой выборке. **(?)** Стало ли лучше? Объясните полученный результат.

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ

# %% [markdown]
# **Задание 17 (бонус, 2 балла)**. Реализуйте трансформер, который строит разбиение карты по шестигранной решётке с помощью библиотеки [H3](https://github.com/uber/h3-py) и вычисляет признаки на основе такого разбиения.
#
# Признаки могут быть самые разные: расстояние между точкой старта и финиша, посчитанное в количестве шестиугольников; статистика по числу поездок и по их продолжительности в соседних шестиугольниках.
#
# Важно: производительность библиотеки существенно зависит от количества шестиугольников на карте (определяется параметром resolution). Подберите такое разрешение, при котором ваш код будет работать за приемлемое время.
#
# При построении признаков старайтесь не допустить утечки целевой переменной --- в противном случае хорошего качества на тестовой выборке достичь не получится.
#
# Измерьте качество после добавления новых признаков. За улучшение функционала ошибки на каждые 0.005 на тестовой выборке будет даваться 0.5 бонусных балла. Можно получить до 2 бонусных баллов за это задание.

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ

# %% [markdown]
# **Бонус (0.3 балла)** Вставьте картинку, описывающую ваш опыт выполнения этого ДЗ.

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/a/a3/Redhead_Cat_%28%D0%A0%D1%8B%D0%B6%D0%B8%D0%B9_%D0%9A%D0%BE%D1%82%29.jpg" style="width: 400px">
